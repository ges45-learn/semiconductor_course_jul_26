# %% [markdown]
# <a href="https://colab.research.google.com/github/ges45-learn/Module2/blob/main/Constants.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# *hc* = 1240 eV·nm
# 1 J = 1eV = 1.602e10-19 C
# h = 4.136 × 10⁻¹⁵ eV·s

# %%
L = 589
hc = 1240
E = 0
o = 1.2
Lc = 0
hJs = 6.62607015 * 10**-34

E = hc / L
print(f"{E:.3e}eV")

Kmax = E - o
print(f"Kmax: {Kmax:.2e}")

Lc = hc / o
print(f"wavelength_cutoff: {Lc:.2f} nm")

w_person = hJs / 65
print(f"w_person: {w_person:e} nm ")
# Out:
# 2.105e+00eV
# Kmax: 9.05e-01
# wavelength_cutoff: 1033.33 nm
# w_person: 1.019395e-35 nm

# %%
# charge carriers. conduction is movement of carriers

e = 1.4e6
h = 5e5
E = 2e4
ye = e / E
yh = h / E
print(ye)
print(yh)
ans = ye * 0.5 * E
print(ans)
# Out:
# 70.0
# 25.0
# 700000.0

# %%
n = 1 * 10**16
q = 1.602 * 10**-19
u = 1350

c = n * q * u
print(f"conductivity: {c:.3e}")
# Out:
# conductivity: 2.163e+00
